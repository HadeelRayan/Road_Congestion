# %%
import pandas as pd

# %%
import gmaps
import gmaps.datasets
import requests

# %%
gmaps.configure(api_key='AIzaSyD9tQPZVuDERe52dNwiWmU4vvCh2403fRY')

# %%
# URL of the file to be downloaded
url = "https://drive.google.com/uc?export=download&id=1BT1BDDFu0wHiopo1qL5OF0sfw1FB2K_P"

# Send a GET request to the URL
response = requests.get(url)

# Path where the file will be saved
file_path = "peak_volume.csv"  # Change the extension based on your file type

# Write the content of the response to a file
with open(file_path, "wb") as file:
    file.write(response.content)

print(f"File downloaded and saved as {file_path}")

# Load the dataset
peak_vol = pd.read_csv(file_path)

# Ensure the dataset is in the correct format (latitude, longitude, magnitude)
locations = peak_vol[['latitude', 'longitude']]
weights = peak_vol['magnitude']

# Create the heatmap layer
fig = gmaps.figure(map_type='HYBRID')
heatmap_layer = gmaps.heatmap_layer(locations, weights=weights)
fig.add_layer(heatmap_layer)

# Display the figure
fig
# Out:
# File downloaded and saved as peak_volume.csv
# Figure(layout=FigureLayout(height='420px'))
